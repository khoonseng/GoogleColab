# %% [markdown]
# <a href="https://colab.research.google.com/github/khoonseng/GoogleColab/blob/PostClassExercise/Git_Post_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10 * 10
print(a)
# Out:
# 100
