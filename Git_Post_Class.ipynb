# %% [markdown]
# <a href="https://colab.research.google.com/github/khoonseng/GoogleColab/blob/FeatureBranch2/Git_Post_Class.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 10 * 10
print(a)
# Out:
# 100

# %%
b = 20 + 2
print(b)
# Out:
# 22

# %%
c = a - b
print(c)
# Out:
# 78
